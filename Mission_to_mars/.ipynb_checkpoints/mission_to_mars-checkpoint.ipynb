# %%
#import dependencies
from bs4 import BeautifulSoup
from splinter import Browser
from pprint import pprint
import pandas as pd
import pymongo
import requests

# %%
#define browser
executable_path = {'executable_path':'C:\\chromedriver_win32\\chromedriver.exe' }
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://mars.nasa.gov/news/'
browser.visit(url)

# %%
#iterate through all pages
#For this code  igot till the link is displayed

for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    content_titles = soup.find_all('div', class_='content_title')[1:]
    
    for title in content_titles:
#        print(title.prettify())
       link =title.find('a')
#        print(link)
       news_url=link['href']
#        news_url= link.find('a')['href']
       print(news_url)
# Out:
# /news/8645/mars-helicopter-attached-to-nasas-perseverance-rover/
# /news/8641/nasas-perseverance-mars-rover-gets-its-wheels-and-air-brakes/
# /news/8716/nasa-to-broadcast-mars-2020-perseverance-launch-prelaunch-activities/
# /news/8695/the-launch-is-approaching-for-nasas-next-mars-rover-perseverance/
# /news/8692/nasa-to-hold-mars-2020-perseverance-rover-launch-briefing/
# /news/8659/alabama-high-school-student-names-nasas-mars-helicopter/
# /news/8645/mars-helicopter-attached-to-nasas-perseverance-rover/
# /news/8641/nasas-perseverance-mars-rover-gets-its-wheels-and-air-brakes/
# /news/8716/nasa-to-broadcast-mars-2020-perseverance-launch-prelaunch-activities/
# /news/8695/the-launch-is-approaching-for-nasas-next-mars-rover-perseverance/
# /news/8645/mars-helicopter-attached-to-nasas-perseverance-rover/
# /news/8641/nasas-perseverance-mars-rover-gets-its-wheels-and-air-brakes/
# /news/8716/nasa-to-broadcast-mars-2020-perseverance-launch-prelaunch-activities/
# ...

# %%
#This is the code to get the title of the nasa latest link
for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    content_titles =soup.find_all('div', class_='content_title')[1].get_text()
print(content_titles)
# Out:
# NASA Engineers Checking InSight's Weather Sensors

# %%
#iterate through all pages
#now i am checking the title
for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    content_titles = soup.find_all('div', class_='content_title').get_text()
    
    for title in content_titles:
#        print(title.prettify())
       link =title.find('a')
      
     
# #        news_url=link['href']
#        news_url= link.find('a')['href']
#        print(news_url.get_text())
#        news_title =link.find('a')[target="_self"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-ccf44e31681a> in <module>
#       7     soup = BeautifulSoup(html, 'html.parser')
#       8
# ----> 9     content_titles = soup.find_all('div', class_='content_title').get_text()
#      10
#      11     for title in content_titles:
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2079         """Raise a helpful exception to explain a common code fix."""
#    2080         raise AttributeError(
# -> 2081             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2082         )
#
# ...

# %%
#Result displayed for only one tiltle and paragraph(correct code)
#iterate through all pages


for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    
    abc=soup.select_one("ul.item_list li.slide")
    news_title = abc.find('div', class_='content_title').get_text()
    print(news_title)
    
    news_p= abc.find('div',class_ ='article_teaser_body').get_text()
    print(news_p)
# Out:
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# ...

# %%
# This code need to be the final one


html = browser.html
#parse HTML with Beautiful soup
soup = BeautifulSoup(html, 'html.parser')


abc=soup.select_one("ul.item_list li.slide")
news_title = abc.find('div', class_='content_title').get_text()
# print(news_title)
print('news_title=','"',news_title,'"')

news_p= abc.find('div', class_ ='article_teaser_body').get_text()
# print(news_p)
print('news_p=','"', news_p,'"')
# Out:
# news_title= " NASA Engineers Checking InSight's Weather Sensors "
# news_p= " An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft. "

# %%
#checking  the code for one title and corresponding paragraph working fine with this code
#iterate through all pages


for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    
    abc=soup.select_one("ul.item_list li.slide")
    content_titles = abc.find('div', class_='content_title').get_text()
    print(content_titles)
    
    content_paragraph= abc.find('div',class_ ='article_teaser_body').get_text()
    print(content_paragraph)
    
    
    
#     for title in content_titles:
       
# #         select_one("ul.item_list li.slide")

#         soup.select_one
#         link =title.find('a')
#         print(link)
#         print(content_titles)
# Out:
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# NASA Engineers Checking InSight's Weather Sensors
# ...

# %%
#iterate through all pages

for page in range(1,10):
    #HTML Object
    html = browser.html
    #parse HTML with Beautiful soup
    soup = BeautifulSoup(html, 'html.parser')
    
    news_titles = soup.find_all('div', class_='image_and_description_container')
    
    for title in news_titles:
        link =title.find('a')
        print(link)
        href =link['href']
        print(href.prettify())
